# %% [markdown]
# Assignment Selenium

# %%
! pip install selenium
! pip install webdriver-manager
! pip install pandas
# Out:
# Requirement already satisfied: selenium in c:\users\sandeep\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\sandeep\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\sandeep\anaconda3\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sandeep\anaconda3\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sandeep\anaconda3\lib\site-packages (from selenium) (2023.5.7)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\sandeep\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\sandeep\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\sandeep\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\sandeep\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\sandeep\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sandeep\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\sandeep\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sandeep\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sandeep\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sandeep\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sandeep\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: webdriver-manager in c:\users\sandeep\anaconda3\lib\site-packages (3.8.6)
# Requirement already satisfied: requests in c:\users\sandeep\anaconda3\lib\site-packages (from webdriver-manager) (2.29.0)
# Requirement already satisfied: python-dotenv in c:\users\sandeep\anaconda3\lib\site-packages (from webdriver-manager) (1.0.0)
# Requirement already satisfied: tqdm in c:\users\sandeep\anaconda3\lib\site-packages (from webdriver-manager) (4.65.0)
# Requirement already satisfied: packaging in c:\users\sandeep\anaconda3\lib\site-packages (from webdriver-manager) (23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sandeep\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandeep\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandeep\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandeep\anaconda3\lib\site-packages (from requests->webdriver-manager) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\sandeep\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.6)
# Requirement already satisfied: pandas in c:\users\sandeep\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sandeep\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sandeep\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sandeep\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\sandeep\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
import selenium
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.chrome.service import Service

import time

# %%
driver = selenium.webdriver.Chrome()

# %%
url ="https://www.naukri.com/"
driver.get(url)

# %%
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location= driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[6]")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#job title of the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#job location of the given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#company name of the given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#job experience of the given page
experience_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
#printing the length
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                     Title                                           Location  \
# 0            Data Analyst                                Bangalore/Bengaluru
# 1            Data Analyst  Bangalore/ Bengaluru, Karnataka, Gurgaon/ Guru...
# 2            Data Analyst                                Bangalore/Bengaluru
# 3            Data Analyst  Bangalore/Bengaluru, Hyderabad/Secunderabad, Pune
# 4            Data Analyst  Bangalore/Bengaluru, Hyderabad/Secunderabad, Pune
# 5            Data Analyst                                Bangalore/Bengaluru
# 6          Data Analyst I                                Bangalore/Bengaluru
# 7            Data Analyst                                Bangalore/Bengaluru
# 8            Data Analyst                                Bangalore/Bengaluru
# 9  Data Analyst with ANSR                    Bangalore/ Bengaluru, Karnataka
#
#            Company_name            Experience
# 0           Eastvantage           Eastvantage
# 1             Delhivery             Delhivery
# 2        Everest Vacuum        Everest Vacuum
# 3             Synechron             Synechron
# 4     Synchron Infotech     Synchron Infotech
# 5                   ANZ                   ANZ
# 6                Cerner                Cerner
# 7     Persolkelly India     Persolkelly India
# 8  Paychex It Solutions  Paychex It Solutions
# 9                  ANSR                  ANSR

# %% [markdown]
# # Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results youget.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
import selenium
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.chrome.service import Service

import time

# %%
driver = selenium.webdriver.Chrome()

# %%
url ="https://www.naukri.com/"
driver.get(url)

# %%
designation= driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[1]/div/div/div/div[1]/div/input")
designation.send_keys('Data Scientist')

# %%
location= driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[6]")
search.click()

# %%
job_title = []#title of job
job_location = []#location
company_name = []

# %%
# scrraping job title from given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
# scrraping company name from given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
# scrraping job Location from given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
#printing the length
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company':company_name})
df
# Out:
#                                                Title  \
# 0                            Data Science Specialist
# 1                                     Data Scientist
# 2                   Analystics & Modeling Specialist
# 3                     Data Scientist -ML, DL, Python
# 4                                     DATA SCIENTIST
# 5                                     Data Scientist
# 6  ACN - Applied Intelligence - Finance - Data Sc...
# 7                              Senior Data Scientist
# 8                      Sr . Data Scientist / Manager
# 9                                     Data Scientist
#
#                                             Location            Company
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...          Accenture
# 1            Bangalore/Bengaluru, Mumbai (All Areas)                PwC
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...          Accenture
# 3                                Bangalore/Bengaluru              Capco
# 4                                Bangalore/Bengaluru            Walmart
# 5  Hybrid - Bangalore/ Bengaluru, Karnataka, Noid...            HCLTech
# 6  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...          Accenture
# 7                        Bangalore/Bengaluru, Mumbai  Fractal Analytics
# 8       Bangalore/Bengaluru, Noida, Gurgaon/Gurugram   Novitas Infotech
# 9       Bangalore/Bengaluru, Noida, Gurgaon/Gurugram   Novitas Infotech

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get thewebpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the searchbutton.
# 4. Then apply the location filter and salary filter by checking the respectiveboxes
# 5. Then scrape the data for the first 10 jobs results youget.
# 6. Finally create a dataframe of the scrapeddata.
# Note: All of the above steps have to be done in code. No step is to be done manually

# %%
import selenium
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.chrome.service import Service

import time

# %%
driver = selenium.webdriver.Chrome()

# %%
url = "https://www.naukri.com"
driver.get(url)

# %%
# entering the designation as required in the question
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys("Data Scientist")
# filter the salary
search = driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()
# filter the location 
locationss = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]')
locationss.click()
# filter the salary
salary = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
salary.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[111], line 8
#       6 search.click()
#       7 # filter the location
# ----> 8 locationss = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]')
#       9 locationss.click()
#      10 # filter the salary
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     737     by = By.CSS_SELECTOR
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]"}
#   (Session info: chrome=115.0.5790.99); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00AFA813+48355]
# 	(No symbol) [0x00A8C4B1]
# 	(No symbol) [0x00995358]
# 	(No symbol) [0x009C09A5]
# 	(No symbol) [0x009C0B3B]
# 	(No symbol) [0x009EE232]
# 	(No symbol) [0x009DA784]
# 	(No symbol) [0x009EC922]
# 	(No symbol) [0x009DA536]
# 	(No symbol) [0x009B82DC]
# 	(No symbol) [0x009B93DD]
# 	GetHandleVerifier [0x00D5AABD+2539405]
# 	GetHandleVerifier [0x00D9A78F+2800735]
# 	GetHandleVerifier [0x00D9456C+2775612]
# 	GetHandleVerifier [0x00B851E0+616112]
# 	(No symbol) [0x00A95F8C]
# 	(No symbol) [0x00A92328]
# 	(No symbol) [0x00A9240B]
# 	(No symbol) [0x00A84FF7]
# 	BaseThreadInitThunk [0x759A7D59+25]
# 	RtlInitializeExceptionChain [0x7715B79B+107]
# 	RtlClearBits [0x7715B71F+191]

# %%
# create empty lists to store the scraped data
DataScience_job = []
DataScience_company_name = []
DataScience_job_location = []
DataScience_experience_required = []

# %%
# scrraping job title from given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
# scrraping company name from given page
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
# scrraping job Location from given page
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
# scrraping job experience from given page
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)
# scrraping job Location from given page
salary_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft "]')
for i in salary_tags[0:10]:
    salary=i.text
    job_salary.append(salary)

# %%
print(len(job_title),len(job_location),len(company_name),len(job_salary),len(experience_required))
# Out:
# 10 10 10 10 10

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required,'Salary':job_salary})
df
# Out:
#                               Title  \
# 0           Data Science Specialist
# 1                    Data Scientist
# 2  Analystics & Modeling Specialist
# 3             Senior Data Scientist
# 4                    Data Scientist
# 5               Lead Data Scientist
# 6   Senior Data Scientist, CAT Proc
# 7    Data Scientist -ML, DL, Python
# 8                    DATA SCIENTIST
# 9                    Data Scientist
#
#                                             Location       Company_name  \
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...          Accenture
# 1            Bangalore/Bengaluru, Mumbai (All Areas)                PwC
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...          Accenture
# 3                        Mumbai, Bangalore/Bengaluru  Fractal Analytics
# 4                                       Mumbai, Pune        Tata Nexarc
# 5                                             Mumbai  Here Technologies
# 6                                             Mumbai           Mondelez
# 7                                Bangalore/Bengaluru              Capco
# 8                                Bangalore/Bengaluru            Walmart
# 9  Hybrid - Noida, Uttar Pradesh, Bangalore/ Beng...            HCLTech
#
#   Experience         Salary
# 0    2-4 Yrs  Not disclosed
# 1    3-6 Yrs  Not disclosed
# 2    6-8 Yrs  Not disclosed
# 3   5-10 Yrs  Not disclosed
# 4    3-6 Yrs  Not disclosed
# 5    4-9 Yrs  Not disclosed
# 6    4-8 Yrs  Not disclosed
# 7    2-6 Yrs  Not disclosed
# 8    4-8 Yrs  Not disclosed
# 9   7-12 Yrs  Not disclosed

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. ProductDescription
# 3. Price
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url :https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data asusual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page asusual
# 6. Repeat this until you get data for 100sunglasses.
# Note: That all of the above steps have to be done by coding only and not manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = selenium.webdriver.Chrome()

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
ser_glass = driver.find_element(By.XPATH,"/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
ser_glass.send_keys("Sunglasses")

# %%
search_btn = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search_btn.click()

# %%
Brand=[]
Product_Description=[]
Price=[]
Discount=[]

# %%
URL=[]
for i in range(0,3):
    S_g_url=driver.find_elements(By.XPATH,'//a[@class="_2UzuFa"]')
    for i in S_g_url:
        URL.append(i.get_attribute('href'))
    # Clicking on NEXT button at end of page
    driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]').click()
SEARCH&ppt=sp&ppn=sp&ssid=bygsqnq4k00000001689929190158&qH=0ff7a11a5902c9f7',
#  'https://www.flipkart.com/bkge-retro-square-sunglasses/p/itm0581544ee32c4?pid=SGLFZEWEAWZGBFZU&lid=LSTSGLFZEWEAWZGBFZUBMQG4O&marketplace=FLIPKART&q=Sunglasses&store=26x&srno=s_1_20&otracker=search&otracker1=search&fm=Search&iid=5c50af85-e8da-44f4-9572-d6fb08c78fe5.SGLFZEWEAWZGBFZU.SEARCH&ppt=sp&ppn=sp&ssid=bygsqnq4k00000001689929190158&qH=0ff7a11a5902c9f7']

# %%
for i in URL[:100]:
    driver.get(i)
    try:
        brand=driver.find_element(By.XPATH,"//span[@class='G6XhRU']").text
        Brand.append(brand)
        description=driver.find_element(By.XPATH,"//span[@class='B_NuCI']").text
        Product_Description.append(description)
        price=driver.find_element(By.XPATH,"//div[@class='_30jeq3 _16Jk6d']").text
        Price.append(price)
    except NoSuchElementException:
        Brand.append("NaN")
        Product_Description.append("NaN")
        Price.append("NaN")

# %%
Sunglasses=pd.DataFrame({})
Sunglasses['Brand']=Brand[:100]
Sunglasses['Product_Description']=Product_Description[:100]
Sunglasses['Price']=Price[:100]

# %%
Sunglasses
# Out:
#          Brand                                Product_Description Price
# 0   Elligator   UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹168
# 1     Styloze   Riding Glasses, Night Vision Wayfarer Sunglass...  ₹182
# 2        SRPM   UV Protection Wayfarer Sunglasses (50)  (For M...  ₹194
# 3    Fastrack   UV Protection Rectangular Sunglasses (Free Siz...  ₹539
# 4     eyedens   UV Protection Butterfly Sunglasses (Free Size)...  ₹599
# ..         ...                                                ...   ...
# 95   Fastrack   Gradient, UV Protection Wayfarer Sunglasses (F...  ₹649
# 96    DEIXELS   Polarized, UV Protection, Riding Glasses Wayfa...  ₹211
# 97    Aachive   Night Vision Round Sunglasses (Free Size)  (Fo...  ₹799
# 98  Elligator   UV Protection, Mirrored Wayfarer Sunglasses (5...  ₹229
# 99       BKGE   Polarized, UV Protection Retro Square Sunglass...  ₹199
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market
# place=FLIPKART
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = selenium.webdriver.Chrome()

# %%
url ='https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market'
driver.get(url)

# %%
driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div[1]/div[2]/div[3]/div/div/div/div[1]/div').click()

# %%
from selenium.common.exceptions import StaleElementReferenceException
#creating empty lists
# Create empty lists to store the required data
rating=[]
review=[]
full_review=[]

# %%
# Define the start and end page numbers
start = 0
end = 10

# %%
# Loop through the pages
for page in range(start, end):
    # Find all the elements for rating tag and append their text to the rating list
    rating_tag = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tag:
        rating.append(i.text)
    
    # Find all the elements for review tag and append their text to the review list
    review_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review_tag:
        review.append(i.text)
    
    # Find all the elements for full review tag and append their text to the full review list
    full_review_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_review_tag:
        full_review.append(i.text)
    
    # Find the next button and click on it
    nextbutton = driver.find_element(By.CLASS_NAME,'_1LKTO3')
    nextbutton.click()
    # Wait for 3 seconds for the next page to load
    time.sleep(3)

# %%
# Get only the first 100 items from each of the lists
rating = rating[:100]
review = review[:100]
full_review = full_review[:100]

# %%
# Create a pandas dataframe using the data obtained and store it in a variable named df
df = pd.DataFrame({"Rating":rating, "Review":review, "Full Review":full_review})
 # Set the DataFrame index to start from 1 instead of the default 0
df.index = range(1, len(df)+1)
df
# Out:
#     Rating                 Review  \
# 1        5               Terrific
# 2        5         Classy product
# 3        5              Wonderful
# 4        5              Brilliant
# 5        5              Must buy!
# ..     ...                    ...
# 96       5  Mind-blowing purchase
# 97       5              Excellent
# 98       5      Terrific purchase
# 99       5         Simply awesome
# 100      5                 Super!
#
#                                            Full Review
# 1                                       Very very good
# 2    Camera is awesome\nBest battery backup\nA perf...
# 3                               This is amazing at all
# 4                                     Excellent Phone.
# 5                                  It’s really awesome
# ..                                                 ...
# 96                                        Photos super
# 97                                    Best camera ever
# 98                                  Value for money 🖤🖤
# 99   Really satisfied with the Product I received.....
# 100                        Good product 👌I love iPhone
#
# [100 rows x 3 columns]

# %% [markdown]
# Q6: Scrape data forfirst 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. ProductDescription
# 3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = selenium.webdriver.Chrome()

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
# Entering sneakers in search box-
sneakers=driver.find_element(By.CLASS_NAME,"_3704LK")
sneakers.send_keys('sneakers')

#Clicking on Search Button-
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
# create empty list to store the data
brand =[]
product_description=[]
price =[]

# %%
# Set the start and end pages to scrape
start = 0
end = 3

# Loop through the pages and scrape data
for page in range(start, end):
     # Find all the brand elements on the current page and append them to the brand list
    brand_tag = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tag:
        brand.append(i.text)
        
        
    # Find all the product description elements on the current page and append them to the product description list
    product_tag = driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in product_tag:
        product_description.append(i.text)
        
    # Find all the price elements on the current page and append them to the price list
    price_tag = driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in price_tag:
        price.append(i.text)
        
        
     # Click on the next button to move to the next page
    nexts = driver.find_element(By.CLASS_NAME, '_1LKTO3')
    nexts.click()
    
    # Use a time.sleep() to wait for the next page to load
    time.sleep(3)

# %%
# Truncate the lists to 100 elements if necessary    
Brand = brand[:100]
Product_description =product_description[:100]
Price = price[:100]

# %%
# Create a pandas dataframe from the scraped data and display it
df= pd.DataFrame({'Brand': Brand,'Product Description': Product_description,'Price': Price})
df.index = range(1, len(df)+1)
df
# Out:
#              Brand                                Product Description  \
# 1           BRUTON    !Combo Pack Of 2 Casual Shoes! Sneakers For Men
# 2           Footox  Sneaker for Mens | Casual Shoes | Men Shoes Sn...
# 3             aadi  Synthetic Leather |Lightweight|Comfort|Summer|...
# 4             aadi  Synthetic Leather |Lightweight|Comfort|Summer|...
# 5              SFR                                   Sneakers For Men
# ..             ...                                                ...
# 96          BRUTON                                   Sneakers For Men
# 97          BRUTON  Sneaker for Mens | Casual Shoes | Men Shoes Sn...
# 98   WHITE WALKERS                                   Sneakers For Men
# 99        PrasKing  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...
# 100           aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
#
#                                                  Price
# 1      !Combo Pack Of 2 Casual Shoes! Sneakers For Men
# 2    Sneaker for Mens | Casual Shoes | Men Shoes Sn...
# 3    Synthetic Leather |Lightweight|Comfort|Summer|...
# 4    Synthetic Leather |Lightweight|Comfort|Summer|...
# 5                                     Sneakers For Men
# ..                                                 ...
# 96                                    Sneakers For Men
# 97   Sneaker for Mens | Casual Shoes | Men Shoes Sn...
# 98                                    Sneakers For Men
# 99   Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...
# 100  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then
# set CPU Type filter to “Intel Core i7” as shown in the below image:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = selenium.webdriver.Chrome()

# %%
url = "https://www.amazon.in/"
driver.get(url)

# %%
laptop=driver.find_element(By.XPATH,"//div[@class='nav-search-field ']//input")
laptop.send_keys('Laptop')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
#Creating Empty List for different attributes-
Title=[]
price=[]
Ratings=[]

# %%
start=0
end=1
for page in range(start,end):
    title=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
    for i in title[0:10]:
        Title.append(i.text) 
    prices=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in prices[0:10]:
        price.append(i.text)  
titles_rat=driver.find_elements(By.XPATH,"//div[@class='a-row a-size-small']/span")
for i in titles_rat:
    Rating.append(i.get_attribute("aria-label"))
rating=[]
for i in range(0,len(Rating))[0:20]:
    if i == 0 or  i/2 == i//2:
        rating.append(Rating[i][0:3])

# %%
#checking length for all attributes-
print(len(Title),len(price),len(rating))
# Out:
# 10 10 10

# %%
# Creating Dataframe-
df=pd.DataFrame({'Title':Title,'Price':price,'Ratings':rating})
df
# Out:
#                                                Title     Price Ratings
# 0  Acer Predator Helios 16 Gaming Laptop (Intel C...  2,49,990     3.4
# 1  Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...    34,990     4.0
# 2  Acer Aspire Lite 11th Gen Intel Core i3-1115G4...    32,990     5.0
# 3  Acer Aspire Lite 11th Gen Intel Core i3-1115G4...    31,990     5.0
# 4  Acer Aspire Lite 11th Gen Intel Core i5-1155G7...    45,990     3.8
# 5  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...    37,800     4.1
# 6  Lenovo IdeaPad Slim 3 Intel Core i5 11th Gen 1...    64,990     4.1
# 7  Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...    50,990     3.9
# 8  (Renewed) HP Chromebook 13 G1 6th Gen Intel Co...    23,399     3.7
# 9  Lenovo E41-55 AMD 14-inch HD 220 Nits Antiglar...    14,499     2.7

# %% [markdown]
# # Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on TopQuotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
import selenium
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time

# %%
driver = selenium.webdriver.Chrome()

# %%
driver.get('https://www.azquotes.com/')

# %%
# clicking on top Quotes to search the required data 
quotes = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]')
quotes.click()

# %%
# create empty list to store the data
Quote =[]
Author =[]
Type_of_quotes=[]
# Set the start and end pages to scrape
start = 0
end = 10
# Loop through the pages and scrape data
for page in range(start, end):
    #scrap quote tag and appent it in Quote list
    quote_tag = driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in quote_tag:
        Quote.append(i.text)
     #Scrap author tag and append in Author list   
    author_tag = driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in author_tag:
        Author.append(i.text)
    #scrap type of Quote tag and append in type of quotess list
    type_of_quotes_tag = driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in type_of_quotes_tag:
        Type_of_quotes.append(i.text)

# %%
# Click on the next button to move to the next page
nexts = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[12]')
nexts.click()

# %%
 # Use a time.sleep() to wait for the next page to load
time.sleep(3)
df = pd.DataFrame({'Quotes':Quote,'Author':Author,'Type Of Quotes':Type_of_quotes})
#Set the DataFrame index to start from 1 instead of the default 0
df.index = range(1, len(df)+1)
#print Dataframe
df
# Out:
#                                                  Quotes                Author  \
# 1     The essence of strategy is choosing what not t...        Michael Porter
# 2     One cannot and must not try to erase the past ...            Golda Meir
# 3     Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 4     Death is something inevitable. When a man has ...        Nelson Mandela
# 5     You have to love a nation that celebrates its ...          Erma Bombeck
# ...                                                 ...                   ...
# 996      When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 997   When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 998   If you think you are too small to make a diffe...            Dalai Lama
# 999   God doesn't require us to succeed, he only req...         Mother Teresa
# 1000    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                 Type Of Quotes
# 1     Essence, Deep Thought, Transcendentalism
# 2                    Inspiration, Past, Trying
# 3                          Country, Peace, War
# 4           Inspirational, Motivational, Death
# 5                 4th Of July, Food, Patriotic
# ...                                        ...
# 996                     Music, Sports, Hunting
# 997              Trust, Encouraging, Uplifting
# 998               Inspirational, Funny, Change
# 999                       Success, God, Mother
# 1000       Inspirational, Motivational, Change
#
# [1000 rows x 3 columns]

# %% [markdown]
# # Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
import selenium
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time

# %%
driver = selenium.webdriver.Chrome()

# %%
driver.get('https://www.jagranjosh.com/')

# %%
# clicking on search button to search the required data 
gk = driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a')
gk.click()

# %%
# clicking on search button to search the required data 
pm_btn = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
pm_btn.click()

# %%
# Create empty lists to store the data
Name=[]
Born_Dead=[]
Terms_of_office=[]
Remarks=[]

# %%
#name
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for name in names:
    Name.append(name.text)
    

#borndead
born_dead = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in born_dead:
    Born_Dead.append(i.text)
    

#terms_of_office
terms_of_office = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]')
for i in terms_of_office:
    Terms_of_office.append(i.text.replace('\n', ''))
    
    
#Remarks
remarks = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in remarks:
    Remarks.append(i.text)

# %%
len(Name),len(Born_Dead),len(Term_of_office),len(Remarks)
# Out:
# (19, 19, 0, 19)

# %%
df=pd.DataFrame({"Names":Name,"Born-Dead":Born_Dead,"Terms of office":Terms_of_office,"Remarks":Remarks})
df
# Out:
#                           Names     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
# 18                Narendra Modi   (born 1950)
#
#                                       Terms of office  \
# 0     15 August 1947 to 27 May 196416 years, 286 days
# 1                  27 May 1964 to 9 June 1964,13 days
# 2      9 June 1964 to 11 January 19661 year, 216 days
# 3           11 January 1966 to 24 January 196613 days
# 4   24 January 1966 to 24 March 197711 years, 59 days
# 5     24 March 1977 to  28 July 1979 2 year, 126 days
# 6             28 July 1979 to 14 January 1980170 days
# 7   14 January 1980 to 31 October 19844 years, 291...
# 8   31 October 1984 to 2 December 19895 years, 32 ...
# 9         2 December 1989 to 10 November 1990343 days
# 10           10 November 1990 to 21 June 1991223 days
# 11       21 June 1991 to 16 May 19964 years, 330 days
# 12                  16 May 1996 to 1 June 199616 days
# 13               1 June 1996 to 21 April 1997324 days
# 14            21 April 1997 to 19 March 1998 332 days
# 15      19 March 1998 to 22 May 2004 6 years, 64 days
# 16      22 May 2004 to 26 May 2014   10 years, 4 days
# 17                                 26 May 2014 - 2019
# 18                             30 May 2019- Incumbent
#
#                                               Remarks
# 0   The first prime minister of India and the long...
# 1                            First acting PM of India
# 2   He has given the slogan of 'Jai Jawan Jai Kisa...
# 3                                                   -
# 4                First female Prime Minister of India
# 5   Oldest to become PM (81 years old) and first t...
# 6             Only PM who did not face the Parliament
# 7   The first lady who served as PM for the second...
# 8                Youngest to become PM (40 years old)
# 9   First PM to step down after a vote of no confi...
# 10              He belongs to  Samajwadi Janata Party
# 11                          First PM from South India
# 12                             PM for shortest tenure
# 13                          He belongs to  Janata Dal
# 14                                             ------
# 15   The first non-congress PM who completed a ful...
# 16                                      First Sikh PM
# 17  4th Prime Minister of India who served two con...
# 18  First non-congress PM with two consecutive ten...

# %% [markdown]
# # Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpagehttps://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make the dataframe.

# %%
import selenium
import pandas as pd
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import time

# %%
driver = selenium.webdriver.Chrome()

# %%
driver.get('https://www.motor1.com/')

# %%
# enter the text in the search box
data = driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/button')
data.send_keys('50 Most expensive cars in the world')

# %%
# click on the search button
searchs= driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]')
searchs.click()

# %%
# click on the 50 most expensive cars section
cars = driver.find_element(By.XPATH,'/html/body/div[10]/div[9]/div/div[1]/div/div/div[3]/div/div[1]/h3')
cars.click()

# %%
cars = []
names_50expcars = driver.find_elements(By.XPATH,"//h3[@class='subheader']")
for i in names_50expcars:
        cars.append(i.text)
cars.pop()
# Out:
# 'Most Expensive Cars In The World'

# %%
prices = []
prices_50expcars = driver.find_elements(By.XPATH,"//strong")

for j in prices_50expcars:
        prices.append(j.text)
prices.pop(4)
# Out:
# 'Price: $1.7 Million'

# %%
print(len(cars),len(prices))
# Out:
# 50 50

# %%
most_expensive=pd.DataFrame({"NAME OF THE CAR":cars,"PRICE OF THE CAR IN ($)":prices})
most_expensive
# Out:
#                     NAME OF THE CAR      PRICE OF THE CAR IN ($)
# 0                     De Tomaso P72          Price: $1.3 Million
# 1                 Ferrari LaFerrari          Price: $1.4 Million
# 2                     Pagani Huayra          Price: $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C          Price: $1.7 Million
# 5                     Ferrari Monza          Price: $1.7 Million
# 6                Gordon Murray T.33          Price: $1.7 Million
# 7                 Koenigsegg Gemera          Price: $1.7 Million
# 8                       Zenvo TSR-S          Price: $1.7 Million
# 9                Hennessey Venom F5          Price: $1.8 Million
# 10                  Bentley Bacalar          Price: $1.9 Million
# 11    Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 12           Bentley Mulliner Batur          Price: $2.0 Million
# 13                     Deus Vayanne          Price: $2.0 Million
# 14                      SSC Tuatara         Price: $2.0 Million*
# 15                      Lotus Evija          Price: $2.1 Million
# 16              Aston Martin Vulcan          Price: $2.3 Million
# 17                       Delage D12          Price: $2.3 Million
# 18                McLaren Speedtail          Price: $2.3 Million
# 19                     Rimac Nevera          Price: $2.4 Million
# 20                    Pagani Utopia          Price: $2.5 Million
# 21             Pininfarina Battista          Price: $2.5 Million
# 22                Ferrari FXX K Evo          Price: $2.6 Million
# 23               Gordon Murray T.50          Price: $2.6 Million
# 24             Lamborghini Countach          Price: $2.6 Million
# 25         Mercedes-AMG Project One          Price: $2.7 Million
# 26              Aston Martin Victor          Price: $3.0 Million
# 27      Hennessey Venom F5 Roadster                 $3.0 Million
# 28                 Koenigsegg Jesko          Price: $3.0 Million
# 29            Aston Martin Valkyrie          Price: $3.2 Million
# 30        W Motors Lykan Hypersport          Price: $3.4 Million
# 31                    McLaren Solus                 $3.5 Million
# 32        Pagani Huayra Roadster BC          Price: $3.5 Million
# 33         Bugatti Chiron Pur Sport          Price: $3.6 Million
# 34                 Lamborghini Sian          Price: $3.6 million
# 35                 Koenigsegg CC850          Price: $3.7 Million
# 36  Bugatti Chiron Super Sport 300+          Price: $3.9 Million
# 37               Lamborghini Veneno          Price: $4.5 Million
# 38                   Bugatti Bolide          Price: $4.7 Million
# 39                  Bugatti Mistral          Price: $5.0 Million
# 40              Pagani Huayra Imola          Price: $5.4 Million
# 41                     Bugatti Divo          Price: $5.8 Million
# 42              SP Automotive Chaos          Price: $6.4 Million
# 43                 Pagani Codalunga          Price: $7.4 Million
# 44         Mercedes-Maybach Exelero          Price: $8.0 Million
# 45               Bugatti Centodieci          Price: $9.0 Million
# 46          Bugatti Chiron Profilée         Price: $10.8 Million
# 47             Rolls-Royce Sweptail         Price: $12.8 Million
# 48         Bugatti La Voiture Noire         Price: $13.4 Million
# 49           Rolls-Royce Boat Tail*  Price: $28.0 Million (est.)
